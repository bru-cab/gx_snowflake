# %%
from snowflake.snowpark.session import Session
from configs.config import snowflake_conn_prop_local as snowflake_conn_prop
session = Session.builder.configs(snowflake_conn_prop).create()

# %%
import pandas as pd
import json

df_sql = session.table("citibike_2.validation.trips_validation_raw")
data = df_sql.collect()
df = pd.DataFrame(data) 
print(df)
# Out:
#     RUNSTATUS                                              RUNID  \
# 0       False  {\n  "run_name": "20231220-044028-my-pandas_ru...
# 1       False  {\n  "run_name": "20231220-044246-my-pandas_ru...
# 2       False  {\n  "run_name": "20231220-050942-my-pandas_ru...
# 3       False  {\n  "run_name": "20231220-052129-my-pandas_ru...
# 4       False  {\n  "run_name": "20231220-085359-my-pandas_ru...
# 5       False  {\n  "run_name": "20231226-062812-my-pandas_ru...
# 6       False  {\n  "run_name": "20231227-110158-my-pandas_ru...
# 7       False  {\n  "run_name": "20231227-112708-my-pandas_ru...
# 8       False  {\n  "run_name": "20231227-112824-my-pandas_ru...
# 9       False  {\n  "run_name": "20231227-112954-my-pandas_ru...
# 10      False  {\n  "run_name": "20231227-113120-my-pandas_ru...
#
#                                         RUNVALIDATION
# 0   [\n  {\n    "evaluation_parameters": {},\n    ...
# 1   [\n  {\n    "evaluation_parameters": {},\n    ...
# 2   [\n  {\n    "evaluation_parameters": {},\n    ...
# 3   [\n  {\n    "evaluation_parameters": {},\n    ...
# 4   [\n  {\n    "evaluation_parameters": {},\n    ...
# 5   [\n  {\n    "evaluation_parameters": {},\n    ...
# 6   [\n  {\n    "evaluation_parameters": {},\n    ...
# 7   [\n  {\n    "evaluation_parameters": {},\n    ...
# 8   [\n  {\n    "evaluation_parameters": {},\n    ...
# 9   [\n  {\n    "evaluation_parameters": {},\n    ...
# 10  [\n  {\n    "evaluation_parameters": {},\n    ...

# %%
import json
from IPython.display import display, Markdown

# Load and display the JSON
json_object = json.loads(df['RUNVALIDATION'].iloc[6])
display(Markdown("```json\n" + json.dumps(json_object, indent=4) + "\n```"))
# Out:
# ```json
# [
#     {
#         "evaluation_parameters": {},
#         "meta": {
#             "active_batch_definition": {
#                 "batch_identifiers": {
#                     "default_identifier_name": "default_identifier_TRIPS"
#                 },
#                 "data_asset_name": "PandasData",
#                 "data_connector_name": "default_runtime_data_connector_name",
#                 "datasource_name": "TRIPS"
#             },
#             "batch_markers": {
#                 "ge_load_time": "20231227T190158.980857Z",
#                 "pandas_data_fingerprint": "b03307607acd6b3302fa0e3f53c5e7c4"
#             },
#             "batch_spec": {
#                 "batch_data": "PandasDataFrame",
#                 "data_asset_name": "PandasData"
#             },
#             "checkpoint_name": "checkpointname",
#             "expectation_suite_name": "expecationsuitename",
#             "great_expectations_version": "0.15.14",
#             "run_id": {
#                 "run_name": "20231227-110158-my-pandas_run-name-template",
#                 "run_time": "2023-12-27T11:01:58.965553+00:00"
#             },
#             "validation_time": "20231227T190159.102204Z"
#         },
#         "results": [
#             {
#                 "exception_info": {
#                     "exception_message": null,
#                     "exception_traceback": null,
#                     "raised_exception": false
#                 },
#                 "expectation_config": {
#                     "expectation_type": "expect_column_values_to_be_in_set",
#                     "kwargs": {
#                         "batch_id": "ede5132cf66231d5edff9d3818568727",
#                         "column": "USERTYPE",
#                         "value_set": [
#                             "Subscriber"
#                         ]
#                     },
#                     "meta": {}
#                 },
#                 "meta": {},
#                 "result": {
#                     "element_count": 10000,
#                     "missing_count": 0,
#                     "missing_percent": 0,
#                     "partial_unexpected_counts": [
#                         {
#                             "count": 20,
#                             "value": "Customer"
#                         }
#                     ],
#                     "partial_unexpected_index_list": null,
#                     "partial_unexpected_list": [
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer",
#                         "Customer"
#                     ],
#                     "unexpected_count": 1528,
#                     "unexpected_percent": 15.28,
#                     "unexpected_percent_nonmissing": 15.28,
#                     "unexpected_percent_total": 15.28
#                 },
#                 "success": false
#             },
#             {
#                 "exception_info": {
#                     "exception_message": null,
#                     "exception_traceback": null,
#                     "raised_exception": false
#                 },
#                 "expectation_config": {
#                     "expectation_type": "expect_column_mean_to_be_between",
#                     "kwargs": {
#                         "batch_id": "ede5132cf66231d5edff9d3818568727",
#                         "column": "TRIPDURATION",
#                         "max_value": 14,
#                         "min_value": 13
#                     },
#                     "meta": {}
#                 },
#                 "meta": {},
#                 "result": {
#                     "observed_value": 1102.4413
#                 },
#                 "success": false
#             },
#             {
#                 "exception_info": {
#                     "exception_message": null,
#                     "exception_traceback": null,
#                     "raised_exception": false
#                 },
#                 "expectation_config": {
#                     "expectation_type": "expect_column_values_to_not_be_null",
#                     "kwargs": {
#                         "batch_id": "ede5132cf66231d5edff9d3818568727",
#                         "column": "BIKEID"
#                     },
#                     "meta": {}
#                 },
#                 "meta": {},
#                 "result": {
#                     "element_count": 10000,
#                     "partial_unexpected_counts": [],
#                     "partial_unexpected_index_list": null,
#                     "partial_unexpected_list": [],
#                     "unexpected_count": 0,
#                     "unexpected_percent": 0
#                 },
#                 "success": true
#             }
#         ],
#         "statistics": {
#             "evaluated_expectations": 3,
#             "success_percent": 33.33333333333333,
#             "successful_expectations": 1,
#             "unsuccessful_expectations": 2
#         },
#         "success": false
#     }
# ]
# ```

# %%
evaluated_expectations = [item["statistics"]["evaluated_expectations"] for item in json_object]
print(evaluated_expectations)
# Out:
# [3]

# %%
expectation_types = []

# Loop through the items in json_object
for item in json_object:
    results = item.get("results", [])  # Get the results list or an empty list if not present
    for result in results:
        expectation_type = result.get("expectation_config", {}).get("expectation_type")
        if expectation_type is not None:
            expectation_types.append(expectation_type)

print(expectation_types)
# Out:
# ['expect_column_values_to_be_in_set', 'expect_column_mean_to_be_between', 'expect_column_values_to_not_be_null']

# %%
# Import the necessary libraries
import pandas as pd

# Initialize a list to store the extracted information
extracted_data = []

# Initialize a dictionary to store information for different expectation types
expectation_data = {}

# Assuming json_object contains the provided JSON data
for item in json_object:
    results = item.get("results", [])  # Get the results list or an empty list if not present
    for result in results:
        expectation_type = result.get("expectation_config", {}).get("expectation_type")
        
        # Extract expectation_config and remove batch_id if it exists
        expectation_config = result.get("expectation_config", {}).get("kwargs", {})
        expectation_config.pop("batch_id", None)  # Remove batch_id

        observed_values = result.get("result", {}).get("observed_value")
        success_status = result.get("success", False)
        runtime = item.get("meta", {}).get("run_id", {}).get("run_time")
            
        # Append the extracted information to the list
        extracted_data.append({
            "EXPECTATION_TYPE": expectation_type,
            "RUNTIME": runtime,
            "EXPECTATION_CONFIG": expectation_config,
            "OBSERVED_VALUE": observed_values,
            "SUCCESS_STATUS": success_status,
            "RUNTIME": runtime
        })
            
        # Store the information in a dictionary using the expectation_type as the key
        expectation_data.setdefault(expectation_type, []).append({
            "EXPECTATION_TYPE": expectation_type,
            "RUNTIME": runtime,
            "EXPECTATION_CONFIG": expectation_config,
            "OBSERVED_VALUE": observed_values,
            "SUCCESS_STATUS": success_status,
        })

# Print or use the extracted information organized by expectation type
for expectation_type, data_list in expectation_data.items():
    print(f"Expectation Type: {expectation_type}")
    for data in data_list:
        print(f"Expectation config: {data.get('EXPECTATION_CONFIG')}")
        print(f"Observed_value: {data.get('OBSERVED_VALUE')}")
        print(f"Success Status: {data.get('SUCCESS_STATUS')}")
        print(f"Runtime: {data.get('RUNTIME')}")
    print("-" * 40)  # Print a separator between each expectation type
# Out:
# Expectation Type: expect_column_values_to_be_in_set
# Expectation config: {'column': 'USERTYPE', 'value_set': ['Subscriber']}
# Observed_value: None
# Success Status: False
# Runtime: 2023-12-27T11:01:58.965553+00:00
# ----------------------------------------
# Expectation Type: expect_column_mean_to_be_between
# Expectation config: {'column': 'TRIPDURATION', 'max_value': 14, 'min_value': 13}
# Observed_value: 1102.4413
# Success Status: False
# Runtime: 2023-12-27T11:01:58.965553+00:00
# ----------------------------------------
# Expectation Type: expect_column_values_to_not_be_null
# Expectation config: {'column': 'BIKEID'}
# Observed_value: None
# Success Status: True
# Runtime: 2023-12-27T11:01:58.965553+00:00
# ----------------------------------------

# %%
# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Display the DataFrame
print(df)
# Out:
#                       EXPECTATION_TYPE                           RUNTIME  \
# 0    expect_column_values_to_be_in_set  2023-12-27T11:01:58.965553+00:00
# 1     expect_column_mean_to_be_between  2023-12-27T11:01:58.965553+00:00
# 2  expect_column_values_to_not_be_null  2023-12-27T11:01:58.965553+00:00
#
#                                   EXPECTATION_CONFIG  OBSERVED_VALUE  \
# 0  {'column': 'USERTYPE', 'value_set': ['Subscrib...             NaN
# 1  {'column': 'TRIPDURATION', 'max_value': 14, 'm...       1102.4413
# 2                               {'column': 'BIKEID'}             NaN
#
#    SUCCESS_STATUS
# 0           False
# 1           False
# 2            True

# %%
# CREATE TABLE TO UPLOAD CLEAN RESULTS

#   create or replace TABLE CITIBIKE_2.VALIDATION.TRIPS_VALIDATION_CLEAN (
#  	"EXPECTATION_TYPE" VARCHAR(16777216),
#  	"RUNTIME" TIMESTAMP_NTZ(9),
#  	"EXPECTATION_CONFIG" VARCHAR(16777216),
#  	"OBSERVED_VALUE" VARCHAR(16777216),
#  	"SUCCESS_STATUS" BOOLEAN);

# %%
from snowflake.snowpark.session import Session
from configs.config import snowflake_conn_prop_local as snowflake_conn_prop
import json

# Create a session object with Snowflake
session = Session.builder.configs(snowflake_conn_prop).create()

# Assuming df is your DataFrame with data
table_name = 'citibike_2.validation.TRIPS_VALIDATION_CLEAN'

# Process each row and create a list of dictionaries representing each row
data_to_insert = []
for index, row in df.iterrows():
    expectation_type = row['EXPECTATION_TYPE']
    runtime = row['RUNTIME']
    expectation_config = json.dumps(row['EXPECTATION_CONFIG'])
    observed_values = json.dumps(row['OBSERVED_VALUE'])
    success_status = row['SUCCESS_STATUS']

    data_to_insert.append({
        "EXPECTATION_TYPE": expectation_type,
        "RUNTIME": runtime,
        "EXPECTATION_CONFIG": expectation_config,
        "OBSERVED_VALUE": observed_values,
        "SUCCESS_STATUS": success_status
    })

# Create a DataFrame from the list of dictionaries
df_to_insert = session.create_dataframe(data_to_insert)

# Write the DataFrame to the Snowflake table
df_to_insert.write.mode("append").save_as_table(table_name)

# Print the number of rows inserted
print(f"Number of rows inserted: {len(data_to_insert)}")

# Close the session
session.close()
# Out:
# Number of rows inserted: 3
